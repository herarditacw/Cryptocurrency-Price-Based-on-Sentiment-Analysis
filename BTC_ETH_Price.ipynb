# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

#Stationary Test
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss

import warnings
warnings.filterwarnings('ignore')

# %%
btc_df = pd.read_csv(r'/content/coin_Bitcoin.csv')
eth_df = pd.read_csv(r'/content/coin_Ethereum.csv')

# %% [markdown]
# ## Data Exploration

# %%
btc_df.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
btc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2991 entries, 0 to 2990
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        2991 non-null   int64
#  1   Name       2991 non-null   object
#  2   Symbol     2991 non-null   object
#  3   Date       2991 non-null   object
#  4   High       2991 non-null   float64
#  5   Low        2991 non-null   float64
#  6   Open       2991 non-null   float64
#  7   Close      2991 non-null   float64
#  8   Volume     2991 non-null   float64
#  9   Marketcap  2991 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 233.8+ KB

# %%
btc_df.describe()
# Out:
#                SNo          High           Low          Open         Close  \
# count  2991.000000   2991.000000   2991.000000   2991.000000   2991.000000
# mean   1496.000000   6893.326038   6486.009539   6700.146240   6711.290443
# std     863.571653  11642.832456  10869.032130  11288.043736  11298.141921
# min       1.000000     74.561096     65.526001     68.504997     68.431000
# 25%     748.500000    436.179001    422.879486    430.445496    430.569489
# 50%    1496.000000   2387.610107   2178.500000   2269.889893   2286.409912
# 75%    2243.500000   8733.926948   8289.800459   8569.656494   8576.238715
# max    2991.000000  64863.098908  62208.964366  63523.754869  63503.457930
#
#              Volume     Marketcap
# count  2.991000e+03  2.991000e+03
# mean   1.090633e+10  1.208761e+11
# std    1.888895e+10  2.109438e+11
# min    0.000000e+00  7.784112e+08
# 25%    3.036725e+07  6.305579e+09
# 50%    9.460360e+08  3.741503e+10
# 75%    1.592015e+10  1.499957e+11
# ...

# %% [markdown]
# ### Ethereum

# %%
eth_df.tail()
# Out:
#        SNo      Name Symbol                 Date         High          Low  \
# 2155  2156  Ethereum    ETH  2021-07-02 23:59:59  2155.596496  2021.824808
# 2156  2157  Ethereum    ETH  2021-07-03 23:59:59  2237.567155  2117.590013
# 2157  2158  Ethereum    ETH  2021-07-04 23:59:59  2384.286857  2190.837703
# 2158  2159  Ethereum    ETH  2021-07-05 23:59:59  2321.922836  2163.041394
# 2159  2160  Ethereum    ETH  2021-07-06 23:59:59  2346.294874  2197.919385
#
#              Open        Close        Volume     Marketcap
# 2155  2109.892677  2150.040364  3.179621e+10  2.505527e+11
# 2156  2150.835025  2226.114282  1.743336e+10  2.594475e+11
# 2157  2226.550382  2321.724112  1.878711e+10  2.706217e+11
# 2158  2321.922836  2198.582464  2.010379e+10  2.562978e+11
# 2159  2197.919385  2324.679449  2.089186e+10  2.710286e+11

# %%
eth_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        2160 non-null   int64
#  1   Name       2160 non-null   object
#  2   Symbol     2160 non-null   object
#  3   Date       2160 non-null   object
#  4   High       2160 non-null   float64
#  5   Low        2160 non-null   float64
#  6   Open       2160 non-null   float64
#  7   Close      2160 non-null   float64
#  8   Volume     2160 non-null   float64
#  9   Marketcap  2160 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 168.9+ KB

# %%
eth_df.describe()
# Out:
#                SNo         High          Low         Open        Close  \
# count  2160.000000  2160.000000  2160.000000  2160.000000  2160.000000
# mean   1080.500000   398.258568   365.592589   382.879899   383.910691
# std     623.682612   628.082281   566.611523   599.719862   601.078766
# min       1.000000     0.482988     0.420897     0.431589     0.434829
# 25%     540.750000    14.265225    13.190950    13.757600    13.819200
# 50%    1080.500000   205.124631   193.302715   198.425096   198.643691
# 75%    1620.250000   396.494561   375.146804   386.264935   386.435272
# max    2160.000000  4362.350542  3785.848603  4174.635873  4168.701049
#
#              Volume     Marketcap
# count  2.160000e+03  2.160000e+03
# mean   7.057058e+09  4.172084e+10
# std    1.064526e+10  6.909184e+10
# min    1.021280e+05  3.221363e+07
# 25%    3.825102e+07  1.135576e+09
# 50%    2.148880e+09  2.070063e+10
# 75%    9.629136e+09  4.231010e+10
# max    8.448291e+10  4.828819e+11

# %% [markdown]
# ## Data Visualization

# %%
eth_df.Date = pd.to_datetime(eth_df.Date)
btc_df.Date = pd.to_datetime(btc_df.Date)

# %%
eth_df.index = eth_df.Date
btc_df.index = btc_df.Date

# %%
btc_df['2020-01-01':'2020-05-29']
# Out:
#                       SNo     Name Symbol                Date         High  \
# Date
# 2020-01-01 23:59:59  2439  Bitcoin    BTC 2020-01-01 23:59:59  7254.330611
# 2020-01-02 23:59:59  2440  Bitcoin    BTC 2020-01-02 23:59:59  7212.155253
# 2020-01-03 23:59:59  2441  Bitcoin    BTC 2020-01-03 23:59:59  7413.715099
# 2020-01-04 23:59:59  2442  Bitcoin    BTC 2020-01-04 23:59:59  7427.385794
# 2020-01-05 23:59:59  2443  Bitcoin    BTC 2020-01-05 23:59:59  7544.496872
# ...                   ...      ...    ...                 ...          ...
# 2020-05-25 23:59:59  2584  Bitcoin    BTC 2020-05-25 23:59:59  8951.005638
# 2020-05-26 23:59:59  2585  Bitcoin    BTC 2020-05-26 23:59:59  8991.967625
# 2020-05-27 23:59:59  2586  Bitcoin    BTC 2020-05-27 23:59:59  9203.320515
# 2020-05-28 23:59:59  2587  Bitcoin    BTC 2020-05-28 23:59:59  9546.319602
# 2020-05-29 23:59:59  2588  Bitcoin    BTC 2020-05-29 23:59:59  9573.666817
#
# ...

# %% [markdown]
# ### Bitcoin

# %%
# Resampling to monthly frequency, considering only numeric columns
df_month = btc_df.resample('M').mean(numeric_only=True)

# Resampling to annual frequency, considering only numeric columns
df_year = btc_df.resample('A-DEC').mean(numeric_only=True)

# Resampling to quarterly frequency, considering only numeric columns
df_Q = btc_df.resample('Q-DEC').mean(numeric_only=True)

# %%
# PLOTS
fig = plt.figure(figsize=[15, 7])
plt.suptitle('Bitcoin, mean USD', fontsize=22)

plt.subplot(221)
plt.plot(btc_df.Close, '-', label='By Days')
plt.legend()

plt.subplot(222)
plt.plot(df_month.Close, '-', label='By Months')
plt.legend()

plt.subplot(223)
plt.plot(df_Q.Close, '-', label='By Quarters')
plt.legend()

plt.subplot(224)
plt.plot(df_year.Close, '-', label='By Years')
plt.legend()

# plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15, 6))
plt.plot(btc_df['2020-01-01 00:00:00':'2021-02-04 00:00:00'].Close )
plt.style.use('seaborn-v0_8-whitegrid')
plt.ylabel('Nilai Tukar USD/BTC')
plt.xlabel('Tanggal')
plt.grid(True)

# %% [markdown]
# ### Ethereum

# %%
# Resampling to monthly frequency, considering only numeric columns
df_month = eth_df.resample('M').mean(numeric_only=True)

# Resampling to annual frequency, considering only numeric columns
df_year = eth_df.resample('A-DEC').mean(numeric_only=True)

# Resampling to quarterly frequency, considering only numeric columns
df_Q = eth_df.resample('Q-DEC').mean(numeric_only=True)

# %%
# PLOTS
fig = plt.figure(figsize=[15, 7])
plt.suptitle('Ethereum, mean USD', fontsize=22)

plt.subplot(221)
plt.plot(eth_df.Close, '-', label='By Days')
plt.legend()

plt.subplot(222)
plt.plot(df_month.Close, '-', label='By Months')
plt.legend()

plt.subplot(223)
plt.plot(df_Q.Close, '-', label='By Quarters')
plt.legend()

plt.subplot(224)
plt.plot(df_year.Close, '-', label='By Years')
plt.legend()

# plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(15, 6))
plt.plot(eth_df['2020-01-01 00:00:00':'2021-02-04 00:00:00'].Close, c='orange')
plt.style.use('seaborn-v0_8-whitegrid')
plt.ylabel('Nilai Tukar USD/ETH')
plt.xlabel('Tanggal')
plt.grid(True)

# %% [markdown]
# ## Preprocessing

# %%
btc_df = btc_df.loc['20150808235959':]

# %%
btc_d1 = []
btc_d2 = []

for i in range(1, len(btc_df)):
    if btc_df['Close'][i-1] < btc_df['Close'][i]:
        btc_d1.append(1)
    else:
        btc_d1.append(0)
    btc_d2.append(btc_df['Close'][i] - btc_df['Close'][i-1])

# %%
eth_d1 = []
eth_d2 = []

for i in range(1, len(eth_df)):
    if eth_df['Close'][i-1] < eth_df['Close'][i]:
        eth_d1.append(1)
    else:
        eth_d1.append(0)

    eth_d2.append(eth_df['Close'][i] - eth_df['Close'][i-1])

# %%
d = {'Date': btc_df['Date'][:-1], '+1D BTC': btc_d1, '+1D ETH': eth_d1, 'Price Diff BTC':btc_d2, 'Price Diff ETH':eth_d2, 'BTC Volume':btc_df.iloc[:-1, 8], 'ETH Volume':eth_df.iloc[:-1, 8]}
df = pd.DataFrame(data= d)
df = df.drop('Date', axis=1)

# %%
df
# Out:
#                      +1D BTC  +1D ETH  Price Diff BTC  Price Diff ETH  \
# Date
# 2015-08-08 23:59:59        1        0        4.085999       -0.051428
# 2015-08-09 23:59:59        0        1       -0.613007        0.006551
# 2015-08-10 23:59:59        1        1        5.915985        0.359412
# 2015-08-11 23:59:59        0        1       -4.009979        0.149580
# 2015-08-12 23:59:59        0        1       -2.296021        0.610230
# ...                      ...      ...             ...             ...
# 2021-07-01 23:59:59        1        1      324.930937       36.434841
# 2021-07-02 23:59:59        1        1      771.499812       76.073918
# 2021-07-03 23:59:59        1        1      619.231364       95.609830
# 2021-07-04 23:59:59        0        0    -1541.777310     -123.141648
# 2021-07-05 23:59:59        1        1      489.190995      126.096985
#
#                        BTC Volume    ETH Volume
# Date
# 2015-08-08 23:59:59  5.853300e+07  6.741880e+05
# ...

# %%
ax1 = sns.countplot(x=df['2020-01-01 00:00:00':'2021-02-04 00:00:00']['+1D BTC'])
ax1.bar_label(ax1.containers[0])
plt.show()

# %%
ax2 = sns.countplot(x =df['2020-01-01 00:00:00':'2021-02-04 00:00:00']['+1D ETH'])
ax2.bar_label(ax2.containers[0])
plt.show()

# %%
fig = plt.figure(figsize=(20, 5))
sns.lineplot(x=df['2020-01-01 00:00:00':'2021-02-04 00:00:00'].index,
             y=df['2020-01-01 00:00:00':'2021-02-04 00:00:00']['+1D BTC'],
             label='BTC')
plt.show()

fig = plt.figure(figsize=(20, 5))
sns.lineplot(x=df['2020-01-01 00:00:00':'2021-02-04 00:00:00'].index,
             y=df['2020-01-01 00:00:00':'2021-02-04 00:00:00']['+1D ETH'],
             label='ETH', color='orange')
plt.show()

# %%
fig = plt.figure(figsize=(10, 5))
# Pass data as a DataFrame and specify 'x' and 'y'
sns.lineplot(x=df['2020-01-01 00:00:00':'2021-02-04 00:00:00'].index,
             y=df['2020-01-01 00:00:00':'2021-02-04 00:00:00']['Price Diff BTC'],
             label='BTC')
plt.show()

fig = plt.figure(figsize=(10, 5))
# Pass data as a DataFrame and specify 'x' and 'y'
sns.lineplot(x=df['2020-01-01 00:00:00':'2021-02-04 00:00:00'].index,
             y=df['2020-01-01 00:00:00':'2021-02-04 00:00:00']['Price Diff ETH'],
             label='ETH', color='orange')
plt.show()

# %%
df['BTC_close'] = btc_df['Close']
df['ETH_close'] = eth_df['Close']

df.to_csv('Prices.csv')
