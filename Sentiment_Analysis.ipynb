# %%
from transformers import AutoModelForSequenceClassification
from transformers import AutoTokenizer, AutoConfig
from scipy.special import softmax
import numpy as np
import pandas as pd
from tqdm import tqdm

import seaborn as sns
import matplotlib.pyplot as plt

# %%
MODEL = "cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
config = AutoConfig.from_pretrained(MODEL)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %%
def preprocess(text):
    new_text = []
    for t in text.split(" ") or text.split("\n"):
        t = '@user' if t.startswith('@') and len(t) > 1 else t
        t = 'http' if t.startswith('http') else t
        new_text.append(t)
    return " ".join(new_text)

# %%
def polarity_scores_roberta(text):
    labels = [-1, 0, 1]
    text = preprocess(text)
    encoded_input = tokenizer(text, return_tensors='pt', max_length=511, truncation=True)
    output = model(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    i, = np.where(scores == scores.max())
    return scores_dict, labels[i[0]], encoded_input, output

# %%
pd.DataFrame({'Text with Special Token': ['<s>', '@', 'user', '@', 'user', 'shr', '##ek', '5', ':', 'invest', 'all', 'your', 'money', 'in', 'bitcoin', '<s>'],
            'Input Ids':[    0,  1039, 12105,   787, 12105,   840, 27313,   195,    35, 12814,
            70,   110,   418,    11, 11388,     2], 'Attention Mask':[1 for i in range(16)]
            }).T
# Out:
#                           0     1      2    3      4    5      6    7   8   \
# Text with Special Token  <s>     @   user    @   user  shr   ##ek    5   :
# Input Ids                  0  1039  12105  787  12105  840  27313  195  35
# Attention Mask             1     1      1    1      1    1      1    1   1
#
#                              9    10    11     12  13       14   15
# Text with Special Token  invest  all  your  money  in  bitcoin  <s>
# Input Ids                 12814   70   110    418  11    11388    2
# Attention Mask                1    1     1      1   1        1    1

# %% [markdown]
# ## Bitcoin

# %%
btc_df = pd.read_csv(f'/content/BTC_Tweets_v2.csv', index_col=0)

# %%
btc_df.head()
# Out:
#                         Date  Retweet  Reply  Likes  \
# 0  2020-01-01 18:23:45+00:00       82      1   2978
# 1  2020-01-01 02:20:38+00:00      360     43   2000
# 2  2020-01-01 15:12:05+00:00      160     56   1828
# 3  2020-01-01 02:12:10+00:00      229    140   1789
# 4  2020-01-01 23:58:54+00:00      113    148   1723
#
#                                                Tweet
# 0  @NightlyEspresso @twilightsthorn Shrek 5: Inve...
# 1           This decade was bitcoin just warming up.
# 2  BREAKING: Bitcoin's price just set a new yearl...
# 3  $BTC\n\nI'm pretty sure we're gonna bounce big...
# 4  I bought my wife some Bitcoin to help her unde...

# %%
roberta_result = {}
classes = []
for i, row in tqdm(btc_df.iterrows(), total=len(btc_df)):
    text = preprocess(row['Tweet'])
    result = polarity_scores_roberta(text)
    roberta_result[i] = {**result[0]}
    classes.append(result[1])
# Out:
# 100%|██████████| 73884/73884 [2:34:18<00:00,  7.98it/s]

# %%
btc_df = btc_df.join(pd.DataFrame(roberta_result).T)
btc_df['classes'] = classes

btc_df.head()
# Out:
#                         Date  Retweet  Reply  Likes  \
# 0  2020-01-01 18:23:45+00:00       82      1   2978
# 1  2020-01-01 02:20:38+00:00      360     43   2000
# 2  2020-01-01 15:12:05+00:00      160     56   1828
# 3  2020-01-01 02:12:10+00:00      229    140   1789
# 4  2020-01-01 23:58:54+00:00      113    148   1723
#
#                                                Tweet  roberta_neg  \
# 0  @NightlyEspresso @twilightsthorn Shrek 5: Inve...     0.035846
# 1           This decade was bitcoin just warming up.     0.029965
# 2  BREAKING: Bitcoin's price just set a new yearl...     0.002858
# 3  $BTC\n\nI'm pretty sure we're gonna bounce big...     0.002113
# 4  I bought my wife some Bitcoin to help her unde...     0.514108
#
#    roberta_neu  roberta_pos  classes
# 0     0.865769     0.098386        0
# 1     0.760136     0.209899        0
# 2     0.214380     0.782763        1
# 3     0.070673     0.927214        1
# 4     0.369716     0.116176       -1

# %%
btc_df.to_csv('sentiment_btc_v2.csv')

# %%
btc_df['Date'] = pd.to_datetime(btc_df['Date']).dt.date
btc_df1 = btc_df.groupby('Date')[['roberta_neg', 'roberta_neu', 'roberta_pos']].mean()

# %%
btc_df1 = pd.read_csv(r'/content/sentiment_btc_v2.csv')

btc_df1.Date = pd.to_datetime(btc_df1.Date).dt.floor('D')
btc_df1 = btc_df1.groupby('Date')[['roberta_neg', 'roberta_neu', 'roberta_pos']].sum()

# %%
fig = plt.figure(figsize=(15, 6))
sns.lineplot(x='Date', y='roberta_neu', data=btc_df1, color='b')
sns.lineplot(x='Date', y='roberta_neg', data=btc_df1, color='r')
sns.lineplot(x='Date', y='roberta_pos', data=btc_df1, color='g')
plt.xlabel('Tanggal')
plt.ylabel('Skor Polaritas')
sns.set_style('whitegrid')

plt.legend(['0: Sentimen Netral', '-1: Sentimen Negatif', '1: Sentimen Positif'])
plt.style.reload_library()
plt.show()

# %%
fig = plt.figure(figsize=(6, 5))
btc_df_with_classes = pd.read_csv(r'/content/sentiment_btc_v2.csv')
ax = sns.countplot(x='classes', data=btc_df_with_classes, palette=['r', 'b', 'g'], saturation=0.35)
for container in ax.containers:
    ax.bar_label(container)
plt.xlabel('Klasifikasi Sentimen')
plt.ylabel('Jumlah')
sns.set_style('whitegrid')
plt.show()
# Out:
# <ipython-input-15-23a47bbbc23f>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='classes', data=btc_df_with_classes, palette=['r', 'b', 'g'], saturation=0.35)

# %% [markdown]
# ## Ethereum

# %%
eth_df = pd.read_csv(f'/content/ETH_Tweets_v2.csv', index_col=0)

# %%
eth_df.head()
# Out:
#                         Date  Retweet  Reply  Likes  \
# 0  2020-01-01 08:18:15+00:00      122     57    975
# 1  2020-01-01 20:15:56+00:00      161    179    933
# 2  2020-01-01 01:24:27+00:00       52     29    868
# 3  2020-01-01 12:53:38+00:00       77     47    776
# 4  2020-01-01 06:54:45+00:00      207     84    732
#
#                                                Tweet
# 0  If you bought any crypto and it went up over 1...
# 1  I found @CryptoKitties the most interesting cr...
# 2  Happy New Year to all you great people in the ...
# 3  $ETH\n\nTime to play the range. https://t.co/I...
# 4  Crypto companies by number of fulltime employe...

# %%
roberta_result = {}
classes = []
for i, row in tqdm(eth_df.iterrows(), total=len(eth_df)):
    text = row['Tweet']
    result = polarity_scores_roberta(text)
    roberta_result[i] = {**result[0]}
    classes.append(result[1])
# Out:
# 100%|██████████| 34922/34922 [1:17:49<00:00,  7.48it/s]

# %%
eth_df = eth_df.join(pd.DataFrame(roberta_result).T)
eth_df['classes'] = classes

# %%
eth_df.head()
# Out:
#                         Date  Retweet  Reply  Likes  \
# 0  2020-01-01 08:18:15+00:00      122     57    975
# 1  2020-01-01 20:15:56+00:00      161    179    933
# 2  2020-01-01 01:24:27+00:00       52     29    868
# 3  2020-01-01 12:53:38+00:00       77     47    776
# 4  2020-01-01 06:54:45+00:00      207     84    732
#
#                                                Tweet  roberta_neg  \
# 0  If you bought any crypto and it went up over 1...     0.800818
# 1  I found @CryptoKitties the most interesting cr...     0.001476
# 2  Happy New Year to all you great people in the ...     0.001505
# 3  $ETH\n\nTime to play the range. https://t.co/I...     0.051264
# 4  Crypto companies by number of fulltime employe...     0.013984
#
#    roberta_neu  roberta_pos  classes
# 0     0.171669     0.027513       -1
# 1     0.022359     0.976165        1
# 2     0.009942     0.988553        1
# 3     0.882905     0.065831        0
# 4     0.510773     0.475243        0

# %%
eth_df.to_csv('sentiment_eth_v2.csv')

# %%
eth_df['Date'] = pd.to_datetime(eth_df['Date']).dt.date
eth_df1 = eth_df.groupby('Date')[['roberta_neg', 'roberta_neu', 'roberta_pos']].mean()

# %%
eth_df1 = pd.read_csv(r'/content/sentiment_eth_v2.csv')

eth_df1.Date = pd.to_datetime(eth_df1.Date).dt.floor('D')
eth_df1 = eth_df1.groupby('Date')[['roberta_neg', 'roberta_neu', 'roberta_pos']].sum()

# %%
fig = plt.figure(figsize=(15, 6))
sns.lineplot(x='Date', y='roberta_neu', data=eth_df1, color='b')
sns.lineplot(x='Date', y='roberta_neg', data=eth_df1, color='r')
sns.lineplot(x='Date', y='roberta_pos', data=eth_df1, color='g')
plt.xlabel('Tanggal')
plt.ylabel('Skor Polaritas')
sns.set_style('whitegrid')

plt.legend(['0: Sentimen Netral', '-1: Sentimen Negatif', '1: Sentimen Positif'])

plt.show()

# %%
fig = plt.figure(figsize=(6, 5))
btc_df_with_classes = pd.read_csv(r'/content/sentiment_eth_v2.csv')
ax = sns.countplot(x='classes', data=btc_df_with_classes, palette=['r', 'b', 'g'], saturation=0.35)
for container in ax.containers:
    ax.bar_label(container)
plt.xlabel('Klasifikasi Sentimen')
plt.ylabel('Jumlah')
sns.set_style('whitegrid')
plt.show()
# Out:
# <ipython-input-18-408af9130575>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='classes', data=btc_df_with_classes, palette=['r', 'b', 'g'], saturation=0.35)
